# %%
! pip install requests

! pip install Pillow

# %%
import requests as requests
requests.method(url, params, data, json, headers, cookies, files, auth, timeout, allow_redirects, proxies, verify, stream, cert)

# %%
! pip install beautifulsoup4
# Out:
# ...
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    ------------------------ --------------- 92.2/147.9 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- ------ 122.9/147.9 kB 901.1 kB/s eta 0:00:01
#    -------------------------------------- 147.9/147.9 kB 983.5 kB/s eta 0:00:00
# ...

# %%
import requests

from bs4 import BeautifulSoup

response = requests.get('https://tuoitre.vn/tin-moi-nhat.htm')

soup = BeautifulSoup(response.content, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html id="mainHtml" lang="vi" xmlns="http://www.w3.org/1999/xhtml">
# ...

# %%
doc = Jsoup.connect(url).data("query", "Java").userAgent("Chrome").cookie("auth", "token").timeout(5000).post();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import Document as doc
#       2 doc = Jsoup.connect(url).data("query", "Java").userAgent("Chrome").cookie("auth", "token").timeout(5000).post();
#
# ModuleNotFoundError: No module named 'Document'
