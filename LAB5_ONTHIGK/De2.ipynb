# %% [markdown]
# # Bài 1: (4đ)
#
# Cho dữ liệu `diamonds.csv` với các thông tin về kim cương cũng như giá bán. Thực hiện các công việc dưới đây.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-e26a71a18b69> in <cell line: 7>()
#       5
#       6 from google.colab import drive
# ----> 7 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %% [markdown]
# ## a. (1đ) Đọc dữ liệu và cho biết đâu là dữ liệu định lượng, đâu là dữ liệu định tính.

# %% [markdown]
# ## b. (1đ) Tạo thêm 1 cột `volume` vào dataframe đã có với giá trị là tích của các cột `x`, `y`, và `z`. Sau khi đã tạo, hãy xóa 3 cột `x`, `y` và `z` và xóa các dòng ứng với giá trị của cột `volume` bằng 0.

# %%
# KHÔNG XÓA CELL NÀY
# Out:
#            cut color clarity  depth  table  price     volume
# carat
# 0.23     Ideal     E     SI2   61.5   55.0    326  38.202030
# 0.21   Premium     E     SI1   59.8   61.0    326  34.505856
# 0.23      Good     E     VS1   56.9   65.0    327  38.076885
# 0.29   Premium     I     VS2   62.4   58.0    334  46.724580
# 0.31      Good     J     SI2   63.3   58.0    335  51.917250

# %% [markdown]
# ## c. (0.5đ) Vẽ heatmap cho các dữ liệu `depth`,	`table`,	`price`, và	`volume`.

# %%
# KHÔNG XÓA CELL NÀY
# Out:
# <ipython-input-36-9dbda1678905>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ## d. (0.5đ) Vẽ biểu đồ Histogram cho `Price` với `bins = 50`

# %%
# KHÔNG XÓA CELL NÀY
# Out:
# Highest Price in Diamond dataset:  18823

# %%
# KHÔNG XÓA CELL NÀY
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## e. (0.5) Tạo một DataFrame mới tên `mean_prices` để tính giá trị trung bình dự trên các loại `cut`. Vẽ biểu đồ Bar cho DataFrame mới được tạo.

# %%
# KHÔNG XÓA CELL NÀY
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## f. (0.5đ) Vẽ biểu đồ `scatter' theo `Price` và `Volume`.

# %%
# KHÔNG XÓA CELL NÀY
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Bài 2: (3đ)
# 1. (1đ) Dựa vào số liệu trong quá khứ, ta ước lượng rằng 85% các sản phẩm của một máy sản xuất nào đó là thứ phẩm. Nếu máy này sản xuất 20 sản phẩm mỗi giờ, thì xác suất 48 đến 50 thứ phẩm được sản xuất trong mỗi khoảng thời gian 3 giờ là bao nhiêu?
# 2. Tỷ lệ một loại bệnh bẩm sinh trong dân số là p = 0.1\%. Bệnh này cần sự chăm
# sóc đặc biệt lúc mới sinh. Một trung tâm y tế thường có 500 ca sinh trong một tuần. Tính xác suất để
#
#   (a) (0.5) không có trường hợp nào cần chăm sóc đặc biệt,
#
#   (b) (0.5) có đúng một trường hợp cần chăm sóc đặc biệt,
#
#   (c) (1đ) có nhiều hơn một trường hợp cần chăm sóc đặc biệt.

# %% [markdown]
# # Bài 3 (3đ)
# Trọng lượng X (tính bằng gam) một loại trái cây có phân phối chuẩn $N(\mu, \sigma^2)$, với $\mu = 500$ (gam) và $\sigma^2 = 16\ (\text{gam}^2)$. Trái cây thu hoạch được phân loại theo trọng lượng như sau:
#
# (a) loại 1 : trên 505 gam,
#
# (b) loại 2 : từ 495 đến 505 gam,
#
# (c) loại 3 : dưới 495 gam.
#
# Nhà anh Nam có vườn trái cây thu hoạch được 1000 trái cây. Anh Nam cần chuẩn bị bao đựng trái đây, mỗi bao đựng được khối lượng 25kg. Quy ước làm tròn loại 1 đều cân nặng 550g, loại 2 cân nặng 500g và loại 3 nặng 450g. Hỏi anh Nam cần chuẩn bị bao nhiêu bao đựng cho mỗi loại trái cây?
