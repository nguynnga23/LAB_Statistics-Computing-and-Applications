# %% [markdown]
# # Lab 03 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %%
import numpy as np
from numpy import random
arr = random.randint(0, 1000, size=100)
arr
# Out:
# array([893, 810, 720, 688, 329, 165, 382,  91, 606, 406, 843, 383,  31,
#        291, 594, 387,  42, 617, 690,  40, 391, 582, 809, 703, 821, 737,
#         69, 410,  67, 824, 742, 826, 853,  18, 530, 540, 708,  73, 229,
#        412, 845, 406, 196,  49, 940, 399,  58, 233, 642, 175, 924, 242,
#        633,  70, 554, 484, 406, 997, 390, 121, 222, 929, 790, 215, 848,
#        232, 216, 201, 923, 352, 211,  41, 987, 195, 503, 881, 576, 356,
#        609,   3, 310, 716,  35, 216, 189, 924, 995, 635,  28, 290, 345,
#        135, 808, 180, 221, 576, 389, 185, 420, 598])

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
# 10 phần tử đầu tiên :
print("10 phần tử đầu tiên của arr là:")
print(arr[:10]) 
    
# 5 phần từ cuối cùng :
print("5 phần tử cuối cùng là : ")
print(arr[-5:]) 

# Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100
arr_tm = []
for x in arr:
    if x % 5 == 0 and x > 100:
        arr_tm.append(x)
print("Các phần tử thỏa mãi điều kiện chia hết cho 5 và lớn hơn 100 là:\n", arr_tm)
# Out:
# 10 phần tử đầu tiên của arr là:
# [893 810 720 688 329 165 382  91 606 406]
# 5 phần tử cuối cùng là :
# [576 389 185 420 598]
# Các phần tử thỏa mãi điều kiện chia hết cho 5 và lớn hơn 100 là:
#  [810, 720, 165, 690, 410, 530, 540, 845, 940, 175, 390, 790, 215, 195, 310, 995, 635, 290, 345, 135, 180, 185, 420]

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
a = arr[arr<100]
print(a)
print("Số lượng phần tử nhỏ hơn 100 là :", len(a))
# Out:
# [91 31 42 40 69 67 18 73 49 58 70 41  3 35 28]
# Số lượng phần tử nhỏ hơn 100 là : 15

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print("Tổng mảng : ", arr.sum())
print("Giá trị trung bình : ", arr.mean())
print("Giá trị trung vị : ", np.median(arr))

print("Q1 :", np.quantile(arr, 0.25))
print("Q2 :", np.quantile(arr, 0.5))
print("Q3 :", np.quantile(arr, 0.75))

# print('Tứ phân vị [Q1, Q2, Q3]: ', np.quantile(arr, [0.25, 0.5, 0.75]))
print("Phân vị 20 :", np.quantile(arr, 0.2))
# Out:
# Tổng mảng :  45601
# Giá trị trung bình :  456.01
# Giá trị trung vị :  406.0
# Q1 : 208.5
# Q2 : 406.0
# Q3 : 710.0
# Tứ phân vị [Q1, Q2, Q3]:  [208.5 406.  710. ]
# Phân vị 20 : 184.0

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range(5):
    a = np.random.choice(arr, size=10)
    print(f"Lần {i+1}:", a)
# Out:
# Lần 1: [ 70 708 180 290  28  73 406 790 233 554]
# Lần 2: [853 826 216 688 195  41 690 387 720 598]
# Lần 3: [291 540 420  40 540 484 598 503 809 995]
# Lần 4: [ 69 540  40 576 135 399 924 598 576 635]
# Lần 5: [229  67 412 356 576 175 530  35 554 291]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
unique_e, counts = np.unique(arr, return_counts=True)
# Tìm phần tử xuất hiện nhiều nhất
most_common_element = unique_e[np.argmax(counts)]

# In kết quả
print(f"Phần tử xuất hiện nhiều nhất là {most_common_element} với {np.max(counts)} lần xuất hiện.")

print(np.argmax(np.bincount(arr)))
# Out:
# Phần tử xuất hiện nhiều nhất là 406 với 3 lần xuất hiện.
# 406

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# Your code here

# %%
import numpy as np 
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [2, 4, 1])
plt.title('Sample graph!')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# Your code here

# %%
x1 = np.array([10, 20, 30])
y1 = np.array([20, 40, 10])
x2 = np.array([10, 20, 30])
y2 = np.array([40, 10, 30])

plt.plot(x2, y2, color='blue', label='line1')
plt.plot(x1, y1, color='red', label='line 2')

plt.legend()
plt.title('Đồ thị hai đường thẳng')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# Your code here

# %%
plt.plot([1, 4, 5, 6, 7], [2, 6, 3, 6, 3], marker='o', mfc='orange', mec='red')

plt.title('Sử dụng marker')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# Your code here

# %%
x = np.linspace(0, np.pi + 3)

y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, label='sin(x)')
plt.plot(x, y_cos, label='cos(x)', ls='--')

# plt.xlim(0, 6)
# plt.ylim(-1, 1)

plt.legend(loc="lower left")
plt.grid(True)
plt.title('Đồ thị hàm sin(x) và cos(x)')
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# Your code here

# %%
x = np.linspace(0, np.pi + 3)

y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(2,1,1)
plt.title("Đồ thị sin(x) và cos(x)")
plt.plot(x, y_sin, label='sin(x)')
plt.legend()
plt.subplot(2,1,2)
plt.plot(x, y_cos, label='cos(x)', color='red')
plt.legend()

plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# Your code here

# %%
x = np.array(["Java", "Python", "PHP","JacaScript", "C#", "C++"])
y = np.array([22, 18, 8, 7, 6, 5])
plt.bar(x,y)
plt.title("Mức độ phổ biến của các ngôn ngữ lập trình")
plt.xlabel("Programming Language")
plt.ylabel("Popularity")
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# Your code here

# %%
x = np.array(["Java", "Python", "PHP","JacaScript", "C#", "C++"])
y = np.array([31.27, 24.79, 12.39, 11.27, 10.85, 9.44])
myexplode = [0.2, 0, 0, 0, 0, 0]
plt.pie(y, labels=x, explode = myexplode)
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# Your code here

# %%
# Thay đổi một số tham số
x = np.random.normal(0, 1, 10000) 

plt.hist(x
        , bins=100          # Chia thành 100 cột
        # , density=True      # Giá trị tung độ là mật độ
        # , stacked=True
        # , color='blue'     
        # , edgecolor='white' # màu cạnh
        )

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# Your code here

# %%
x = np.random.normal(size=10000)
plt.boxplot(x=x)
plt.title("Boxplot")
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# Your code here

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
import seaborn as sns

df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="day", y="tip", data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
sns.barplot(x="time", y="tip", data=df)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
plt.hist(df["total_bill"])
plt.xlabel("Tổng hóa đơn")
plt.ylabel("Số lượng hóa đơn")
plt.show()

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.xlabel("Ngày")
plt.ylabel("Tổng hóa đơn")
plt.show()

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.ylabel("Tổng hóa đơn")
plt.show()

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
# Thay đổi màu sắc
sns.scatterplot(x="total_bill", y="tip", data=df, color="red")
plt.xlabel("Tổng hóa đơn")
plt.ylabel("Tiền tip")

plt.show()

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sns.jointplot(x="total_bill", y="tip", data=df)
plt.show()

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sns.pairplot(df)
plt.show()

# Có một số mối quan hệ tương quan rõ ràng, chẳng hạn như:
## total_bill và tip
## total_bill và size
## tip và size

# Ngoài ra, cũng có một số mối quan hệ không tuyến tính, chẳng hạn như:
## total_bill và day
## tip và day

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
plt.subplot(121)
sns.histplot(df[df["time"] == "Lunch"].total_bill, color="red")
plt.title("Lunch")

plt.subplot(122)
sns.histplot(df[df["time"] == "Dinner"].total_bill, color="blue")
plt.title("Dinner")

plt.show()

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
plt.subplot(121)
sns.boxplot(x="time", y="total_bill", data=df)
plt.title("Lunch vs. Dinner")

plt.show()

# %% [markdown]
# ---
